# %% [markdown]
# # HOTEL REVIEWS: ENTITY EXTRACTIONS: BOW, BIGRAMS AND TRIGRAMS FEATURIZATION

# %% [markdown]
# The main objective of this exercise is to device several featurization process that help us to perform Entity Recognition (ER) in a corpus of hotel reviews

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

from pyspark.sql.types import  *
from pyspark.sql.functions import *
from pyspark.sql import *

from pyspark.ml.feature import RegexTokenizer, StopWordsRemover, NGram

from pyspark.ml import Pipeline, PipelineModel

# %%
UDF_docCleaner= udf(lambda doc: " ".join(re.sub('[^0-9a-zA-Z]+', ' ', doc).
                                             lower().
                                             split()
                                        ), StringType() 
                   )

# %%
corpus = spark.read.\
    option("sep", ",").\
    option("header", "true").\
    option("inferSchema", True).\
    csv("gs://manualrg-formacion/hot_rev/data/Hotels_Reviews.csv").\
    withColumn('doc', UDF_docCleaner('review')).persist()

# %%
n = corpus.count()
print('Number of reviews: ', n)
# Out:
# ('Number of reviews: ', 515679)

# %%
n_hotels = corpus.select(col('Hotel_Name')).distinct().count()
print('Number of hotels: ', n_hotels)
# Out:
# ('Number of hotels: ', 1492)

# %% [markdown]
# The dataset contains 515.679 from 1492 hotels placed across Europe, each review is splitted in positive and nevative and a score is given. Our aim is to detect what concepts lead customers to a good or a bad review.

# %%
corpus.printSchema()
# Out:
# root
#  |-- Hotel_Address: string (nullable = true)
#  |-- Additional_Number_of_Scoring: integer (nullable = true)
#  |-- Review_Date: string (nullable = true)
#  |-- Average_Score: double (nullable = true)
#  |-- Hotel_Name: string (nullable = true)
#  |-- Reviewer_Nationality: string (nullable = true)
#  |-- Negative_Review: string (nullable = true)
#  |-- Review_Total_Negative_Word_Count: integer (nullable = true)
#  |-- Total_Number_of_Reviews: integer (nullable = true)
#  |-- Positive_Review: string (nullable = true)
#  |-- Review_Total_Positive_Word_Count: integer (nullable = true)
#  |-- Total_Number_of_Reviews_Reviewer: integer (nullable = true)
#  |-- Reviewer_Score: integer (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- days_since_review_old: string (nullable = true)
#  |-- lat: string (nullable = true)
#  |-- lng: string (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- idhotel: integer (nullable = true)
#  |-- hotel_country: string (nullable = true)
#  |-- review: string (nullable = true)
#  |-- label: integer (nullable = true)
#  |-- flg_same_country: integer (nullable = true)
#  |-- days_since_review: integer (nullable = true)
#  |-- doc: string (nullable = true)

# %%
subset = corpus.limit(10).toPandas()
subset[['Hotel_Name','Negative_Review', 'Positive_Review','review', 'Reviewer_Score']]
# Out:
#            Hotel_Name                                    Negative_Review  \
# 0  11 Cadogan Gardens  Thought the prise of drinks at the bar a littl...
# 1  11 Cadogan Gardens  Nothing in particular just the usual problems ...
# 2  11 Cadogan Gardens  I found the floors in the corridors to be a bi...
# 3  11 Cadogan Gardens  I thought I had booked the refundable rate but...
# 4  11 Cadogan Gardens  Room was far too small for 2 No shelves drawer...
# 5  11 Cadogan Gardens                                        No Negative
# 6  11 Cadogan Gardens                                        No Negative
# 7  11 Cadogan Gardens  Room size and outlook very disappointing Bathr...
# 8  11 Cadogan Gardens                       There was nothing to dislike
# 9  11 Cadogan Gardens                                        No Negative
#
#                                      Positive_Review  \
# 0  We were particularly impressed by the very war...
# 1  The atmosphere and staff were excellent just w...
# 2  Bed was amazingly comfortable The building is ...
# 3                                       Lovely hotel
# 4  Concierge service excellent Bed very comfortab...
# 5  Customer service was above and beyond from all...
# 6  Everything Most comfortable bed Extremely Clen...
# 7  Egg white omelette for breakfast Concierge ver...
# 8  The bed was spacious and very comfy Loads of h...
# 9  slightly older property but still very quaint ...
#
#                                               review  Reviewer_Score
# 0  We were particularly impressed by the very war...              10
# 1  The atmosphere and staff were excellent just w...               9
# 2  Bed was amazingly comfortable The building is ...               9
# 3  Lovely hotel I thought I had booked the refund...              10
# 4  Concierge service excellent Bed very comfortab...               8
# 5  Customer service was above and beyond from all...              10
# 6  Everything Most comfortable bed Extremely Clen...              10
# 7  Egg white omelette for breakfast Concierge ver...               8
# 8  The bed was spacious and very comfy Loads of h...               9
# 9  slightly older property but still very quaint ...              10

# %%
corpus_positive = corpus.where(col('Positive_Review') != 'No Positive')
n_pos = corpus_positive.count()
n_pos
# Out:
# 479609

# %%
corpus_negative = corpus.where(col('Negative_Review') != 'No Negative')
n_neg = corpus_negative.count()
n_neg
# Out:
# 386999

# %% [markdown]
# ## Build a featurization pipeline and obtain three doc-ngram matrices:
# * BOW with simple tokenization
# * BOW with bigrams
# * BOW with trigrams

# %%
regexTokenizer = RegexTokenizer().setInputCol("Positive_Review").setOutputCol("tokens").\
    setPattern("\\s+").\
    setMinTokenLength(2)
remover = StopWordsRemover().setInputCol("tokens").setOutputCol("tokens_rm").\
    setCaseSensitive(False)
bigram = NGram().setInputCol("tokens_rm").setOutputCol("bigrams").setN(2)
trigram = NGram().setInputCol("tokens_rm").setOutputCol("trigrams").setN(3)

stages=[regexTokenizer, remover, bigram, trigram]


featEng_pl = Pipeline().setStages(stages).fit(corpus_positive)
pos_docTerm_df = featEng_pl.transform(corpus_positive)
pos_docTerm_df.limit(5).toPandas()
# Out:
#                                        Hotel_Address  \
# 0  11 Cadogan Gardens Sloane Square Kensington an...
# 1  11 Cadogan Gardens Sloane Square Kensington an...
# 2  11 Cadogan Gardens Sloane Square Kensington an...
# 3  11 Cadogan Gardens Sloane Square Kensington an...
# 4  11 Cadogan Gardens Sloane Square Kensington an...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                           101  08/03/2017            8.7
# 1                           101  07/21/2017            8.7
# 2                           101  07/16/2017            8.7
# 3                           101  07/10/2017            8.7
# 4                           101  07/05/2017            8.7
#
#            Hotel_Name      Reviewer_Nationality  \
# 0  11 Cadogan Gardens            United Kingdom
# 1  11 Cadogan Gardens                 Australia
# 2  11 Cadogan Gardens      United Arab Emirates
# 3  11 Cadogan Gardens  United States of America
# 4  11 Cadogan Gardens                   Ireland
#
#                                      Negative_Review  \
# 0  Thought the prise of drinks at the bar a littl...
# 1  Nothing in particular just the usual problems ...
# 2  I found the floors in the corridors to be a bi...
# 3  I thought I had booked the refundable rate but...
# 4  Room was far too small for 2 No shelves drawer...
#
#    Review_Total_Negative_Word_Count  Total_Number_of_Reviews  \
# 0                                13                      393
# 1                                27                      393
# 2                                41                      393
# 3                                32                      393
# 4                                48                      393
#
#                                      Positive_Review  \
# 0  We were particularly impressed by the very war...
# 1  The atmosphere and staff were excellent just w...
# 2  Bed was amazingly comfortable The building is ...
# 3                                       Lovely hotel
# 4  Concierge service excellent Bed very comfortab...
#
#                          ...                           hotel_country  \
# 0                        ...                          United Kingdom
# 1                        ...                          United Kingdom
# 2                        ...                          United Kingdom
# 3                        ...                          United Kingdom
# 4                        ...                          United Kingdom
#
#                                               review  label flg_same_country  \
# 0  We were particularly impressed by the very war...      1                1
# 1  The atmosphere and staff were excellent just w...      1                0
# 2  Bed was amazingly comfortable The building is ...      1                0
# 3  Lovely hotel I thought I had booked the refund...      1                0
# 4  Concierge service excellent Bed very comfortab...      1                0
#
#   days_since_review                                                doc  \
# 0                 0  we were particularly impressed by the very war...
# 1                13  the atmosphere and staff were excellent just w...
# 2                18  bed was amazingly comfortable the building is ...
# 3                24  lovely hotel i thought i had booked the refund...
# 4                29  concierge service excellent bed very comfortab...
#
#                                               tokens  \
# 0  [we, were, particularly, impressed, by, the, v...
# 1  [the, atmosphere, and, staff, were, excellent,...
# 2  [bed, was, amazingly, comfortable, the, buildi...
# 3                                    [lovely, hotel]
# 4  [concierge, service, excellent, bed, very, com...
#
#                                            tokens_rm  \
# 0  [particularly, impressed, warm, welcome, recei...
# 1  [atmosphere, staff, excellent, expect, small, ...
# 2  [bed, amazingly, comfortable, building, full, ...
# 3                                    [lovely, hotel]
# 4  [concierge, service, excellent, bed, comfortab...
#
#                                              bigrams  \
# 0  [particularly impressed, impressed warm, warm ...
# 1  [atmosphere staff, staff excellent, excellent ...
# 2  [bed amazingly, amazingly comfortable, comfort...
# 3                                     [lovely hotel]
# 4  [concierge service, service excellent, excelle...
#
#                                             trigrams
# 0  [particularly impressed warm, impressed warm w...
# 1  [atmosphere staff excellent, staff excellent e...
# 2  [bed amazingly comfortable, amazingly comforta...
# 3                                                 []
# 4  [concierge service excellent, service excellen...
#
# [5 rows x 29 columns]

# %%
regexTokenizer = RegexTokenizer().setInputCol("Negative_Review").setOutputCol("tokens").\
    setPattern("\\s+").\
    setMinTokenLength(2)
#TODO: erase negations and conjuntions like: but, however, etc.
remover = StopWordsRemover().setInputCol("tokens").setOutputCol("tokens_rm").\
    setCaseSensitive(False)
bigram = NGram().setInputCol("tokens_rm").setOutputCol("bigrams").setN(2)
trigram = NGram().setInputCol("tokens_rm").setOutputCol("trigrams").setN(3)

stages=[regexTokenizer, remover, bigram, trigram]

featEng_pl = Pipeline().setStages(stages).fit(corpus_negative)
neg_docTerm_df = featEng_pl.transform(corpus_negative)
neg_docTerm_df.limit(5).toPandas()
# Out:
#                                        Hotel_Address  \
# 0  11 Cadogan Gardens Sloane Square Kensington an...
# 1  11 Cadogan Gardens Sloane Square Kensington an...
# 2  11 Cadogan Gardens Sloane Square Kensington an...
# 3  11 Cadogan Gardens Sloane Square Kensington an...
# 4  11 Cadogan Gardens Sloane Square Kensington an...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                           101  08/03/2017            8.7
# 1                           101  07/21/2017            8.7
# 2                           101  07/16/2017            8.7
# 3                           101  07/10/2017            8.7
# 4                           101  07/05/2017            8.7
#
#            Hotel_Name      Reviewer_Nationality  \
# 0  11 Cadogan Gardens            United Kingdom
# 1  11 Cadogan Gardens                 Australia
# 2  11 Cadogan Gardens      United Arab Emirates
# 3  11 Cadogan Gardens  United States of America
# 4  11 Cadogan Gardens                   Ireland
#
#                                      Negative_Review  \
# 0  Thought the prise of drinks at the bar a littl...
# 1  Nothing in particular just the usual problems ...
# 2  I found the floors in the corridors to be a bi...
# 3  I thought I had booked the refundable rate but...
# 4  Room was far too small for 2 No shelves drawer...
#
#    Review_Total_Negative_Word_Count  Total_Number_of_Reviews  \
# 0                                13                      393
# 1                                27                      393
# 2                                41                      393
# 3                                32                      393
# 4                                48                      393
#
#                                      Positive_Review  \
# 0  We were particularly impressed by the very war...
# 1  The atmosphere and staff were excellent just w...
# 2  Bed was amazingly comfortable The building is ...
# 3                                       Lovely hotel
# 4  Concierge service excellent Bed very comfortab...
#
#                          ...                           hotel_country  \
# 0                        ...                          United Kingdom
# 1                        ...                          United Kingdom
# 2                        ...                          United Kingdom
# 3                        ...                          United Kingdom
# 4                        ...                          United Kingdom
#
#                                               review  label flg_same_country  \
# 0  We were particularly impressed by the very war...      1                1
# 1  The atmosphere and staff were excellent just w...      1                0
# 2  Bed was amazingly comfortable The building is ...      1                0
# 3  Lovely hotel I thought I had booked the refund...      1                0
# 4  Concierge service excellent Bed very comfortab...      1                0
#
#   days_since_review                                                doc  \
# 0                 0  we were particularly impressed by the very war...
# 1                13  the atmosphere and staff were excellent just w...
# 2                18  bed was amazingly comfortable the building is ...
# 3                24  lovely hotel i thought i had booked the refund...
# 4                29  concierge service excellent bed very comfortab...
#
#                                               tokens  \
# 0  [thought, the, prise, of, drinks, at, the, bar...
# 1  [nothing, in, particular, just, the, usual, pr...
# 2  [found, the, floors, in, the, corridors, to, b...
# 3  [thought, had, booked, the, refundable, rate, ...
# 4  [room, was, far, too, small, for, no, shelves,...
#
#                                            tokens_rm  \
# 0   [thought, prise, drinks, bar, little, excessive]
# 1  [nothing, particular, usual, problems, staying...
# 2  [found, floors, corridors, bit, squeaky, much,...
# 3  [thought, booked, refundable, rate, found, cou...
# 4  [room, far, small, shelves, drawers, store, cl...
#
#                                              bigrams  \
# 0  [thought prise, prise drinks, drinks bar, bar ...
# 1  [nothing particular, particular usual, usual p...
# 2  [found floors, floors corridors, corridors bit...
# 3  [thought booked, booked refundable, refundable...
# 4  [room far, far small, small shelves, shelves d...
#
#                                             trigrams
# 0  [thought prise drinks, prise drinks bar, drink...
# 1  [nothing particular usual, particular usual pr...
# 2  [found floors corridors, floors corridors bit,...
# 3  [thought booked refundable, booked refundable ...
# 4  [room far small, far small shelves, small shel...
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Compute an inverted index from every doc-term matrix
# An inverted index is a data structure that maps from tokens to the set of documents that every token belongs to
# Then, for every token (or ngram) statistics are computed and an analysis is carried out in order to get the most relevant ngrams, that will be a close estimation of the set of entities to extract

# %%
def computeStats(df, label):
  stats= df.agg(sum(label).alias('N1'), count('*').alias('N') ).toPandas()
  stats['N0'] = stats['N']-stats['N1']
  stats['baseline_accuracy'] = stats['N0']/stats['N']
  stats['apriori'] = 1.0-stats['baseline_accuracy']

  return stats

# %%
#corpus_stats = computeStats(docTerm_df, 'label')
#N0 = stats['N0'].values[0]
#N1 = stats['N1'].values[0]
#N = stats['N'].values[0]


pos_stats = computeStats(pos_docTerm_df, 'label')
pos_N0 = stats['N0'].values[0]
pos_N1 = stats['N1'].values[0]
pos_N = stats['N'].values[0]


neg_stats = computeStats(neg_docTerm_df, 'label')
neg_N0 = stats['N0'].values[0]
neg_N1 = stats['N1'].values[0]
neg_N = stats['N'].values[0]

corpus_stats
# Out:
#        N1       N     N0  baseline_accuracy   apriori
# 0  499761  515679  15918           0.030868  0.969132

# %%
def invIdx(tokens_rdd):
    return tokens_rdd.map(lambda doc: (map(lambda tok: (tok, (doc[0], doc[3]) ), doc[2] )) ).\
    flatMap(lambda x: x).groupByKey().map(lambda idx: (idx[0], list(idx[1])) ).\
    map(lambda pair: (pair[0], pair[1], Counter(pair[1]).values(), Counter(pair[1]).keys() )  ).\
    map(lambda tup: (tup[0], tup[1], 
                              reduce(lambda x, y: (x+y), tup[2]), len(tup[2]), 
                              reduce(lambda x, y: x+y, map(lambda pair: pair[1], tup[1])) ) 
       )

# %%
invIdx_schema= StructType().add(StructField('token', StringType(), True)).\
                                add(StructField('TotalFreq', IntegerType(), True)).\
                               add(StructField('DocFreq', IntegerType(), True)).\
                               add(StructField('E', IntegerType(), True))

# %% [markdown]
# Build an inverted index for positive reviews

# %%
pos_rdd_tokens = pos_docTerm_df.rdd.map(lambda row: (row['id'], row['doc'], row['tokens_rm'], row['label']) )
pos_invIdx1_rdd = invIdx(pos_rdd_tokens)
pos_invIdx1_df = pos_invIdx1_rdd.map(lambda row: (row[0], row[2], row[3], row[4]) ).toDF(invIdx_schema)
    
pos_invIdx1_df.limit(10).toPandas()
# Out:
#            token  TotalFreq  DocFreq   E
# 0       povnovic          1        1   1
# 1  unimaginative          2        2   2
# 2      svietlana          1        1   1
# 3       divinely          4        4   4
# 4        midmost          3        2   3
# 5        nunnery          1        1   1
# 6     hisotrical          1        1   1
# 7           foun          1        1   0
# 8      ubeatable          1        1   1
# 9        advices         25       25  25

# %%
pos_rdd_bigrams = pos_docTerm_df.rdd.map(lambda row: (row['id'], row['doc'], row['bigrams'], row['label']) )
pos_invIdx2_rdd = invIdx(pos_rdd_bigrams)
pos_invIdx2_df = pos_invIdx2_rdd.map(lambda row: (row[0], row[2], row[3], row[4]) ).toDF(invIdx_schema)

pos_invIdx2_df.limit(10).toPandas()
# Out:
#                token  TotalFreq  DocFreq   E
# 0        food corner          3        3   3
# 1       pool greatly          1        1   1
# 2  including evening          2        2   2
# 3        wanted last          2        2   2
# 4      evening tasty          1        1   1
# 5        london ritz          3        2   3
# 6       sry pleasant          1        1   1
# 7         helpful wi         11       11  11
# 8     palladium also          2        2   2
# 9         high rises          1        1   1

# %%
pos_rdd_trigrams = pos_docTerm_df.rdd.map(lambda row: (row['id'], row['doc'], row['trigrams'], row['label']) )
pos_invIdx3_rdd = invIdx(pos_rdd_trigrams)
pos_invIdx3_df = pos_invIdx3_rdd.map(lambda row: (row[0], row[2], row[3], row[4]) ).toDF(invIdx_schema)

pos_invIdx3_df.limit(10).toPandas()
# Out:
#                       token  TotalFreq  DocFreq  E
# 0           beds good check          1        1  1
# 1  romantic inner courtyard          1        1  1
# 2        business vic hotel          1        1  1
# 3       good varied service          2        2  2
# 4       comfiest bed pretty          1        1  1
# 5         parisien view try          1        1  1
# 6   upgraded staff friendly          4        4  4
# 7           far though walk          1        1  1
# 8           piazza duomo 24          1        1  1
# 9          like time travel          1        1  1

# %% [markdown]
# Compute statistics for every token in each inverted index

# %%
pos_df_list = [pos_invIdx1_df, pos_invIdx2_df, pos_invIdx3_df]
pos_df_list2 = map(lambda df:
    df.withColumn('review_type', lit('Positive')).\
    withColumn('NE', col('TotalFreq')-col('E')).\
    withColumn('eprop', col('E')/col('TotalFreq')).\
    withColumn('neprop', col('NE')/col('TotalFreq')).\
    withColumn("N1", lit(pos_N1)).withColumn("N0", lit(pos_N0)).\
    withColumn("P1",col("E")/col("N1")).withColumn("P0",col("NE")/col("N0")).\
    withColumn("x",when(col("P1") ==0.0, float('-inf')).\
        when(col("P0") == 0.0, float('inf')).\
        otherwise(col("P1")/col("P0"))).\
    withColumn("WOEValue",when(col("x")==float('-inf'), float('-inf')).\
        when(col("x")==float('inf'),float('inf')).\
        otherwise(log(col("P1")/col("P0")))).\
    withColumn("token_length", length(col("token")).cast(DoubleType())).\
    withColumn("WOEAbs", abs(col("WOEValue"))).\
    withColumn("flg_singleLabel", when( (col("E") ==0.0) | (col("NE") == 0.0), 1).otherwise(0)).\
    sort(col('DocFreq').desc()), df_list)

pos_invIdx1_pd = pos_df_list2[0].limit(100).toPandas()
pos_invIdx2_pd = pos_df_list2[1].limit(100).toPandas()
pos_invIdx3_pd = pos_df_list2[2].limit(100).toPandas()

# %% [markdown]
# Build an inverted index for negative reviews

# %%
neg_rdd_tokens = neg_docTerm_df.rdd.map(lambda row: (row['id'], row['doc'], row['tokens_rm'], row['label']) )
neg_invIdx1_rdd = invIdx(neg_rdd_tokens)
neg_invIdx1_df = neg_invIdx1_rdd.map(lambda row: (row[0], row[2], row[3], row[4]) ).toDF(invIdx_schema)
    
neg_invIdx1_df.limit(10).toPandas()
# Out:
#           token  TotalFreq  DocFreq   E
# 0          fawn          1        1   1
# 1  roomsinclude          1        1   1
# 2      divinely          1        1   1
# 3        colony          3        3   3
# 4    wonderfull          5        5   5
# 5          foun          1        1   0
# 6         apnea          1        1   1
# 7          pony          2        2   1
# 8      revelers         12       12  12
# 9           gag          3        3   3

# %%
neg_rdd_bigrams = neg_docTerm_df.rdd.map(lambda row: (row['id'], row['doc'], row['bigrams'], row['label']) )
neg_invIdx2_rdd = invIdx(neg_rdd_bigrams)
neg_invIdx2_df = neg_invIdx2_rdd.map(lambda row: (row[0], row[2], row[3], row[4]) ).toDF(invIdx_schema)

neg_invIdx2_df.limit(10).toPandas()
# Out:
#                     token  TotalFreq  DocFreq  E
# 0           deal promptly          1        1  1
# 1            games served          1        1  0
# 2          cathedral came          1        1  1
# 3            forever next          1        1  1
# 4              since past          1        1  1
# 5         contacted guest          1        1  1
# 6               tax child          1        1  1
# 7        need experienced          1        1  1
# 8  experiencing breakfast          1        1  1
# 9        opinion slippers          1        1  1

# %%
neg_rdd_trigrams = neg_docTerm_df.rdd.map(lambda row: (row['id'], row['doc'], row['trigrams'], row['label']) )
neg_invIdx3_rdd = invIdx(neg_rdd_trigrams)
neg_invIdx3_df = neg_invIdx3_rdd.map(lambda row: (row[0], row[2], row[3], row[4]) ).toDF(invIdx_schema)

neg_invIdx3_df.limit(10).toPandas()
# Out:
#                           token  TotalFreq  DocFreq  E
# 0              sea get opposite          1        1  1
# 1  entrance difficult strollers          1        1  1
# 2             menu quality good          1        1  1
# 3          money website hotels          1        1  1
# 4            guests afford stay          1        1  0
# 5        guests worthy business          1        1  0
# 6             wasn working wait          2        2  2
# 7        receptionist best room          1        1  1
# 8              see hotel fenced          1        1  1
# 9      curtains dirty corridors          1        1  1

# %%
neg_df_list = [neg_invIdx1_df, neg_invIdx2_df, neg_invIdx3_df]
neg_df_list2 = map(lambda df:
    df.withColumn('review_type', lit('Negative')).\
    withColumn('NE', col('TotalFreq')-col('E')).\
    withColumn('eprop', col('E')/col('TotalFreq')).\
    withColumn('neprop', col('NE')/col('TotalFreq')).\
    withColumn("N1", lit(neg_N1)).withColumn("N0", lit(neg_N0)).\
    withColumn("P1",col("E")/col("N1")).withColumn("P0",col("NE")/col("N0")).\
    withColumn("x",when(col("P1") ==0.0, float('-inf')).\
        when(col("P0") == 0.0, float('inf')).\
        otherwise(col("P1")/col("P0"))).\
    withColumn("WOEValue",when(col("x")==float('-inf'), float('-inf')).\
        when(col("x")==float('inf'),float('inf')).\
        otherwise(log(col("P1")/col("P0")))).\
    withColumn("token_length", length(col("token")).cast(DoubleType())).\
    withColumn("WOEAbs", abs(col("WOEValue"))).\
    withColumn("flg_singleLabel", when( (col("E") ==0.0) | (col("NE") == 0.0), 1).otherwise(0)).\
    sort(col('DocFreq').desc()), df_list)

neg_invIdx1_pd = neg_df_list2[0].limit(100).toPandas()
neg_invIdx2_pd = neg_df_list2[1].limit(100).toPandas()
neg_invIdx3_pd = neg_df_list2[2].limit(100).toPandas()

# %% [markdown]
# Append both DataFrames and write then to GS

# %%
ap=[]
for i,j in zip(pos_df_list2, neg_df_list2):
    df = i.union(j)
    ap.append(df)

# %%
invIdx1_rank_df = ap[0]
invIdx1_rank_df.persist()
invIdx1_rank_df.write.mode("overwrite").option("sep", ",").\
    option("header", "true").\
    csv("gs://manualrg-formacion/hot_rev/data/InvIdx1/")

# %%
invIdx2_rank_df = ap[1]
invIdx2_rank_df.persist()
invIdx2_rank_df.write.mode("overwrite").option("sep", ",").\
    option("header", "true").\
    csv("gs://manualrg-formacion/hot_rev/data/InvIdx2/")

# %%
invIdx3_rank_df = ap[2]
invIdx3_rank_df.persist()
invIdx3_rank_df.write.mode("overwrite").option("sep", ",").\
    option("header", "true").\
    csv("gs://manualrg-formacion/hot_rev/data/InvIdx3/")

# %% [markdown]
# ## Entity Candidates: top 20 most frequent ngrams

# %%
pos_invIdx1_rank_pd = invIdx1_rank_df.where(col('review_type') == lit('Positive')).limit(20).toPandas()
pos_invIdx1_rank_pd
# Out:
#           token  TotalFreq  DocFreq       E review_type     NE     eprop  \
# 0         staff     229290   209738  224386    Positive   4904  0.978612
# 1          room     298282   203214  286060    Positive  12222  0.959025
# 2      location     202687   196217  198528    Positive   4159  0.979481
# 3         hotel     191256   138335  183150    Positive   8106  0.957617
# 4      negative     129478   129373  128935    Positive    543  0.995806
# 5     breakfast     137864   121677  135065    Positive   2799  0.979697
# 6          good     131381   107988  129103    Positive   2278  0.982661
# 7         great     114921    97389  114407    Positive    514  0.995527
# 8      friendly      89468    88015   88877    Positive    591  0.993394
# 9       helpful      80039    78368   79476    Positive    563  0.992966
# 10        clean      74476    72109   73336    Positive   1140  0.984693
# 11          bed      76593    69506   74048    Positive   2545  0.966772
# 12         nice      78589    67735   77697    Positive    892  0.988650
# 13  comfortable      65054    63341   64651    Positive    403  0.993805
# 14        rooms      71600    63050   68859    Positive   2741  0.961718
# 15    excellent      64424    59572   64268    Positive    156  0.997579
# 16        small      57116    51267   54827    Positive   2289  0.959924
# 17      nothing      44701    43524   41763    Positive   2938  0.934274
# 18         stay      47511    42057   45750    Positive   1761  0.962935
# 19      service      42944    38721   41158    Positive   1786  0.958411
#
#       neprop      N1     N0        P1        P0          x  WOEValue  \
# 0   0.021388  499761  15918  0.448987  0.308079   1.457375  0.376637
# 1   0.040975  499761  15918  0.572394  0.767810   0.745489 -0.293715
# 2   0.020519  499761  15918  0.397246  0.261277   1.520404  0.418976
# 3   0.042383  499761  15918  0.366475  0.509235   0.719659 -0.328978
# 4   0.004194  499761  15918  0.257993  0.034112   7.563053  2.023275
# 5   0.020303  499761  15918  0.270259  0.175839   1.536972  0.429814
# 6   0.017339  499761  15918  0.258329  0.143108   1.805131  0.590633
# 7   0.004473  499761  15918  0.228923  0.032290   7.089500  1.958615
# 8   0.006606  499761  15918  0.177839  0.037128   4.789918  1.566513
# 9   0.007034  499761  15918  0.159028  0.035369   4.496284  1.503251
# 10  0.015307  499761  15918  0.146742  0.071617   2.048984  0.717344
# 11  0.033228  499761  15918  0.148167  0.159882   0.926727 -0.076097
# 19  location excellent       7788     7778   7755    Positive   33  0.995763
#
#       neprop      N1     N0        P1        P0          x  WOEValue  \
# 0   0.002465  499761  15918  0.060731  0.004712  12.889554  2.556417
# 1   0.009327  499761  15918  0.050372  0.014889   3.383218  1.218827
# 2   0.002896  499761  15918  0.049598  0.004523  10.965227  2.394729
# 3   0.002990  499761  15918  0.043367  0.004083  10.620178  2.362756
# 4   0.013881  499761  15918  0.039233  0.017339   2.262706  0.816562
# 5   0.008595  499761  15918  0.034853  0.009486   3.674070  1.301300
# 6   0.001994  499761  15918  0.034048  0.002136  15.940601  2.768869
# 7   0.001593  499761  15918  0.023829  0.001194  19.964012  2.993931
# 8   0.009378  499761  15918  0.021560  0.006408   3.364676  1.213332
# 9   0.037352  499761  15918  0.020370  0.024815   0.820875 -0.197385
# 10  0.051354  499761  15918  0.019627  0.033358   0.588378 -0.530386
# 11  0.014818  499761  15918  0.019821  0.009360   2.117572  0.750270
# 12  0.007817  499761  15918  0.019049  0.004712   4.042982  1.396983
# 13  0.019410  499761  15918  0.018095  0.011245   1.609110  0.475681
# 14  0.004439  499761  15918  0.017951  0.002513   7.143433  1.966194
# 15  0.027882  499761  15918  0.017580  0.015831   1.110495  0.104806
# 16  0.006488  499761  15918  0.017466  0.003581   4.877708  1.584675
# 17  0.044238  499761  15918  0.017508  0.025443   0.688144 -0.373758
# 18  0.013144  499761  15918  0.016376  0.006848   2.391472  0.871909
# 19  0.004237  499761  15918  0.015517  0.002073   7.485038  2.012906
#
#     token_length    WOEAbs  flg_singleLabel
# 0           14.0  2.556417                0
# 1           14.0  1.218827                0
# 2           14.0  2.394729                0
# 3           16.0  2.362756                0
# 4           13.0  0.816562                0
# 5           13.0  1.301300                0
# 6           13.0  2.768869                0
# 7           18.0  2.993931                0
# 8           14.0  1.213332                0
# 9           13.0  0.197385                0
# 10          10.0  0.530386                0
# 11          14.0  0.750270                0
# 12          14.0  1.396983                0
# 13          10.0  0.475681                0
# 14          15.0  1.966194                0
# 15          11.0  0.104806                0
# 16          16.0  1.584675                0
# 17          12.0  0.373758                0
# 18          15.0  0.871909                0
# 19          18.0  2.012906                0

# %%
neg_invIdx2_rank_pd = invIdx2_rank_df.where(col('review_type') == 'Negative').limit(20).toPandas()
neg_invIdx2_rank_pd

# %%
pos_invIdx3_rank_pd = invIdx3_rank_df.where(col('review_type') == 'Positive').limit(20).toPandas()
pos_invIdx3_rank_pd
# Out:
#                       token  TotalFreq  DocFreq     E review_type  NE  \
# 0    staff friendly helpful       9634     9627  9601    Positive  33
# 1    friendly helpful staff       6891     6889  6884    Positive   7
# 2   location friendly staff       3626     3626  3617    Positive   9
# 3    staff helpful friendly       3138     3138  3128    Positive  10
# 4          good value money       2930     2917  2905    Positive  25
# 5   within walking distance       2532     2518  2517    Positive  15
# 6      hotel great location       2361     2361  2353    Positive   8
# 7   friendly staff negative       2137     2137  2135    Positive   2
# 8      staff great location       2102     2102  2102    Positive   0
